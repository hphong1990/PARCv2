# %%
from PARC.data.data_em import DataEnergeticMaterials
import matplotlib.pyplot as plt

# %%
# Get data and normalization

data = DataEnergeticMaterials()

state_seq_whole, vel_seq_whole = data.clip_raw_data(dataset_range = (0, 150), 
                                                    dir_dataset = "/scratch/pdy2bw/single_void_new_clip_testing/", 
                                                    n_seq=2, n_state=3, mode_diff = True, tgt_sz = (512,1024), 
                                                    dim_reduce = 4) # Get void_0 - void_150 for training


# state_seq_norm = data.data_normalization(state_seq_whole,3) # Normalizing for state variables
# vel_seq_norm = data.data_normalization(vel_seq_whole,2) # Normalizing for velocity variables
# Out:
# Processed 19 simulation data into State (395, 128, 256, 6) and Velocity (395, 128, 256, 4)

# %%
plt.imshow(state_seq_whole[0,:,:,2])

# %%
for i in range(50):
    plt.imshow(state_seq_whole[i,:,:,0]) # temperature
    # plt.imshow(state_seq_whole[i,:,:,2])  # microstructure
    plt.show()
